# %%
import setting
"""
agent_ddqn = setting.agent_ddqn
agent_ddqn.run_n_epi(render=False)

agent_dqn = setting.agent_dqn
agent_dqn.run_n_epi(render=False)

agent_noise_dqn = setting.agent_noise_dqn
agent_noise_dqn.run_n_epi(render=False)

agent_per_ddqn = setting.agent_per_ddqn
agent_per_ddqn.run_n_epi(render=False)

"""

agent_dqn = setting.agent_dqn
agent_dqn.run_n_epi(render=True)
# Out:
# left train time is 8.271937017087584e-05 hours, 0.00496316221025255 minutes, 0.297789732615153 seconds
# avarage reward is 2.4444444444444446

# %%
import matplotlib.pyplot as plt

plt.plot(agent_dqn.epi_avg_return,'b',label='dqn')
"""
plt.plot(agent_ddqn.epi_avg_return,'r',label='ddqn')
plt.plot(agent_per_ddqn.epi_avg_return,'y',label='per_ddqn')
plt.plot(agent_noise_dqn.epi_avg_return,'g',label='noise_dqn')
"""
plt.show()

# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
import testing

agent_dqn = testing.agent_dqn
agent_dqn.run_n_epi_test(render=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_46373/208206488.py in <module>
#       2
#       3 agent_dqn = testing.agent_dqn
# ----> 4 agent_dqn.run_n_epi(render=True)
#
# ~/program/GymSA2/agent/value_base/DQN.py in run_n_epi(self, render)
#     256             self.config.max_epi = 100000
#     257         for epi in range(1,self.config.max_epi) :
# --> 258             self.step(epi,render = render)
#     259
#     260             if epi % self.config.log_interval == 0 :
#
# ~/program/GymSA2/agent/value_base/DQN.py in step(self, epi, render)
#     166
#     167
# --> 168             reward_ = torch.tensor([reward_], device=self.device).float()
#     169             done_ = torch.tensor([done], device=self.device).float()
#     170             action_ = torch.tensor([action], device=self.device).float()
#
# UnboundLocalError: local variable 'reward_' referenced before assignment
