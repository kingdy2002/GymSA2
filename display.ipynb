# %%
import setting
"""
agent_dqn = setting.agent_dqn
agent_dqn.run_n_epi(render=False)

agent_ddqn = setting.agent_ddqn
agent_ddqn.run_n_epi(render=False)
"""
agent_per_ddqn = setting.agent_per_ddqn
agent_per_ddqn.run_n_epi(render=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9961/628617423.py in <module>
#       8 """
#       9 agent_per_ddqn = setting.agent_per_ddqn
# ---> 10 agent_per_ddqn.run_n_epi(render=False)
#
# ~/program/GymSA2/agent/value_base/PER_DDQN.py in run_n_epi(self, render)
#     224             self.config.max_epi = 100000
#     225         for epi in range(1,self.config.max_epi) :
# --> 226             self.step(epi,render = render)
#     227
#     228             if epi % self.config.log_interval == 0 :
#
# ~/program/GymSA2/agent/value_base/PER_DDQN.py in step(self, epi, render)
#     189
#     190             if self.global_step % self.config.update_interval == 0 and self.global_step > self.config.train_start :
# --> 191                 self.update()
#     192
#     193             if self.global_step % self.config.policy_trans == 0 :
#
# ~/program/GymSA2/agent/value_base/PER_DDQN.py in update(self)
#     203     def update(self) :
#     204
# --> 205         batch , w = self.memory.make_batch()
#     206         if batch == None :
#     207             return
#
# ~/program/GymSA2/modules/memory.py in make_batch(self)
#      57     def make_batch(self) :
#      58         p = np.array(self.td_buffer) / self.td_sum
# ---> 59         index = np.random.choice(range(len(self.td_buffer)), size=self.batch_size, replace=False, p=p)
#      60         batch = [self.memory[i] for i in index ]
#      61         td_batch = [self.td_buffer[i] for i in index ]
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities do not sum to 1

# %%
import matplotlib.pyplot as plt

plt.plot(agent_dqn.epi_avg_return,'b',label='dqn')
plt.plot(agent_ddqn.epi_avg_return,'r',label='ddqn')
plt.show()

# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
import gnwrapper
import gym
env =  gnwrapper.Animation(gym.make('CartPole-v1'))
print(env.observation_space)
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
import setting
setting.config_.hyperparameters['lr']
# Out:
# 0.0001
