# %%
import setting

agent_ = setting.agent_
agent_.run_n_epi(100000,render=False)
# Out:
# /home/kimdongyoung/anaconda3/envs/ai/lib/python3.8/site-packages/ale_py/gym/environment.py:11: DeprecationWarning: Importing atari-py roms won't be supported in future releases of ale-py.
#   import ale_py.roms as roms
# A.L.E: Arcade Learning Environment (version +a54a328)
# [Powered by Stella]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3096/1393261915.py in <module>
#       2
#       3 agent_ = setting.agent_
# ----> 4 agent_.run_n_epi(100000,False)
#
# TypeError: run_n_epi() takes 2 positional arguments but 3 were given

# %%
import matplotlib.pyplot as plt

plt.plot(agent_.epi_return)
plt.show()

# %%
import torch

print(torch.cuda.is_available())
# Out:
# True
